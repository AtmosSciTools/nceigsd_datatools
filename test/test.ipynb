# %%
from nceigsd import NCEIGSDProcessor

processor = NCEIGSDProcessor(
    start_year=2010,
    end_year=2012,
    area=[18, 23, 102, 107],
    output_dir="output/test_output"
)

#processor.download_data()                    # Run data download and processing
processor.plot_station_locations() # Plot station locations with categories
processor.plot_availability_heatmaps()  # Plot heatmaps (if seaborn is available)
# Out:
# Found 36 stations. Starting download and processing...
#
# --- Processing station: 48802099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48802099999.csv
# Error for station 48802099999, year 2010: HTTP Error 404: Not Found
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48802099999.csv
# Error for station 48802099999, year 2011: HTTP Error 404: Not Found
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48802099999.csv
#
# Download completed.
#
# --- Processing station: 48803099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48803099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48803099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48803099999.csv
#
# Download completed.
#
# --- Processing station: 48806099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48806099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48806099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48806099999.csv
#
# Download completed.
#
# --- Processing station: 48808099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48808099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48808099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48808099999.csv
#
# Download completed.
#
# --- Processing station: 48810099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48810099999.csv
# Error for station 48810099999, year 2010: HTTP Error 404: Not Found
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48810099999.csv
# Error for station 48810099999, year 2011: HTTP Error 404: Not Found
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48810099999.csv
#
# Download completed.
#
# --- Processing station: 48819099999 ---
#
# --- Processing station: 48819399999 ---
#
# --- Processing station: 48820099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48820099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48820099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48820099999.csv
#
# Download completed.
#
# --- Processing station: 48823099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48823099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48823099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48823099999.csv
#
# Download completed.
#
# --- Processing station: 48825099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48825099999.csv
# Error for station 48825099999, year 2010: HTTP Error 404: Not Found
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48825099999.csv
# Error for station 48825099999, year 2011: HTTP Error 404: Not Found
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48825099999.csv
#
# Download completed.
#
# --- Processing station: 48825199999 ---
#
# --- Processing station: 48826099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48826099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48826099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48826099999.csv
#
# Download completed.
#
# --- Processing station: 48830099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48830099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48830099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48830099999.csv
#
# Download completed.
#
# --- Processing station: 48831099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48831099999.csv
# Error for station 48831099999, year 2010: HTTP Error 404: Not Found
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48831099999.csv
# Error for station 48831099999, year 2011: HTTP Error 404: Not Found
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48831099999.csv
#
# Download completed.
#
# --- Processing station: 48840099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48840099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48840099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48840099999.csv
#
# Download completed.
#
# --- Processing station: 48843099999 ---
#
# --- Processing station: 48845099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48845099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48845099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48845099999.csv
#
# Download completed.
#
# --- Processing station: 48846099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48846099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48846099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48846099999.csv
#
# Download completed.
#
# --- Processing station: 48925099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48925099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48925099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48925099999.csv
#
# Download completed.
#
# --- Processing station: 48927099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48927099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48927099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48927099999.csv
#
# Download completed.
#
# --- Processing station: 48928099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48928099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48928099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48928099999.csv
#
# Download completed.
#
# --- Processing station: 48930099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48930099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48930099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48930099999.csv
#
# Download completed.
#
# --- Processing station: 48930599999 ---
#
# --- Processing station: 48930699999 ---
#
# --- Processing station: 48932599999 ---
#
# --- Processing station: 48935099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48935099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48935099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48935099999.csv
#
# Download completed.
#
# --- Processing station: 48936599999 ---
#
# --- Processing station: 48936699999 ---
#
# --- Processing station: 48939099999 ---
#
# --- Processing station: 48941099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48941099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48941099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48941099999.csv
#
# Download completed.
#
# --- Processing station: 48943899999 ---
#
# --- Processing station: 48944099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48944099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48944099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48944099999.csv
#
# Download completed.
#
# --- Processing station: 48944599999 ---
#
# --- Processing station: 48945099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48945099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/48945099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/48945099999.csv
#
# Download completed.
#
# --- Processing station: 56989099999 ---
#
# --- Processing station: 59417099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/59417099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2011/59417099999.csv
#
# Download completed.
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2012/59417099999.csv
#
# Download completed.
#
# All results have been saved successfully.
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48802099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48803099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48806099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48808099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48810099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48820099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48823099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48825099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48826099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48830099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48831099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48840099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48845099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48846099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48925099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48927099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48928099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48930099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48935099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48941099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48944099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48945099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_59417099999.png

# %%
from nceigsd import NCEIGSDProcessor

processor = NCEIGSDProcessor(
    start_year=2010,
    end_year=2010,
    area=[18, 23, 102, 107],
    output_dir="output/test_output"
)

processor.download_data()                    # Run data download and processing
processor.plot_station_locations() # Plot station locations with categories
processor.plot_availability_heatmaps()  # Plot heatmaps (if seaborn is available)
# Out:
# Found 36 stations. Starting download and processing...
#
# --- Processing station: 48802099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48802099999.csv
# Error for station 48802099999, year 2010: HTTP Error 404: Not Found
#
# --- Processing station: 48803099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48803099999.csv
#
# Download completed.
#
# --- Processing station: 48806099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48806099999.csv
#
# Download completed.
#
# --- Processing station: 48808099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48808099999.csv
#
# Download completed.
#
# --- Processing station: 48810099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48810099999.csv
# Error for station 48810099999, year 2010: HTTP Error 404: Not Found
#
# --- Processing station: 48819099999 ---
#
# --- Processing station: 48819399999 ---
#
# --- Processing station: 48820099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48820099999.csv
#
# Download completed.
#
# --- Processing station: 48823099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48823099999.csv
#
# Download completed.
#
# --- Processing station: 48825099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48825099999.csv
# Error for station 48825099999, year 2010: HTTP Error 404: Not Found
#
# --- Processing station: 48825199999 ---
#
# --- Processing station: 48826099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48826099999.csv
#
# Download completed.
#
# --- Processing station: 48830099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48830099999.csv
#
# Download completed.
#
# --- Processing station: 48831099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48831099999.csv
# Error for station 48831099999, year 2010: HTTP Error 404: Not Found
#
# --- Processing station: 48840099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48840099999.csv
#
# Download completed.
#
# --- Processing station: 48843099999 ---
#
# --- Processing station: 48845099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48845099999.csv
#
# Download completed.
#
# --- Processing station: 48846099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48846099999.csv
#
# Download completed.
#
# --- Processing station: 48925099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48925099999.csv
#
# Download completed.
#
# --- Processing station: 48927099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48927099999.csv
#
# Download completed.
#
# --- Processing station: 48928099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48928099999.csv
#
# Download completed.
#
# --- Processing station: 48930099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48930099999.csv
#
# Download completed.
#
# --- Processing station: 48930599999 ---
#
# --- Processing station: 48930699999 ---
#
# --- Processing station: 48932599999 ---
#
# --- Processing station: 48935099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48935099999.csv
#
# Download completed.
#
# --- Processing station: 48936599999 ---
#
# --- Processing station: 48936699999 ---
#
# --- Processing station: 48939099999 ---
#
# --- Processing station: 48941099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48941099999.csv
#
# Download completed.
#
# --- Processing station: 48943899999 ---
#
# --- Processing station: 48944099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48944099999.csv
#
# Download completed.
#
# --- Processing station: 48944599999 ---
#
# --- Processing station: 48945099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/48945099999.csv
#
# Download completed.
#
# --- Processing station: 56989099999 ---
#
# --- Processing station: 59417099999 ---
# Downloading: https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/2010/59417099999.csv
#
# Download completed.
#
# All results have been saved successfully.
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48803099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48806099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48808099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48820099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48823099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48826099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48830099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48840099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48845099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48846099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48925099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48927099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48928099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48930099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48935099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48941099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48944099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_48945099999.png
# Saved heatmap to: output/test_output/summaries/availability_heatmap_59417099999.png
